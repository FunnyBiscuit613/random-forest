# %%
import os
path = r'G:\情景模式下的各种变量\GST\SSP585_C/'
file_list = os.listdir(path)

# %%
for i in file_list:
#     print('GST040'+'_SSP370_'+i)
    print(path+i,path+'GST040'+'_SSP585_'+i)
    os.rename(path+i,path+'GST040'+'_SSP585_'+i)
# Out:
# G:\情景模式下的各种变量\GST\SSP585_C/2015.tfw G:\情景模式下的各种变量\GST\SSP585_C/GST040_SSP585_2015.tfw
# G:\情景模式下的各种变量\GST\SSP585_C/2015.tif G:\情景模式下的各种变量\GST\SSP585_C/GST040_SSP585_2015.tif
# G:\情景模式下的各种变量\GST\SSP585_C/2015.tif.aux.xml G:\情景模式下的各种变量\GST\SSP585_C/GST040_SSP585_2015.tif.aux.xml
# G:\情景模式下的各种变量\GST\SSP585_C/2015.tif.ovr G:\情景模式下的各种变量\GST\SSP585_C/GST040_SSP585_2015.tif.ovr
# G:\情景模式下的各种变量\GST\SSP585_C/2015.tif.xml G:\情景模式下的各种变量\GST\SSP585_C/GST040_SSP585_2015.tif.xml
# G:\情景模式下的各种变量\GST\SSP585_C/2016.tfw G:\情景模式下的各种变量\GST\SSP585_C/GST040_SSP585_2016.tfw
# G:\情景模式下的各种变量\GST\SSP585_C/2016.tif G:\情景模式下的各种变量\GST\SSP585_C/GST040_SSP585_2016.tif
# G:\情景模式下的各种变量\GST\SSP585_C/2016.tif.aux.xml G:\情景模式下的各种变量\GST\SSP585_C/GST040_SSP585_2016.tif.aux.xml
# G:\情景模式下的各种变量\GST\SSP585_C/2016.tif.ovr G:\情景模式下的各种变量\GST\SSP585_C/GST040_SSP585_2016.tif.ovr
# G:\情景模式下的各种变量\GST\SSP585_C/2016.tif.xml G:\情景模式下的各种变量\GST\SSP585_C/GST040_SSP585_2016.tif.xml
# ...
